# %%
import numpy as np

# Load the .npy file
elevation_data = np.load('output/CA3982012144020181108/elevation.npy', allow_pickle=True)

# Show the content
print(elevation_data)
# Out:
# {'data': array([[132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763],
#        [132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763],
#        [132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763],
#        ...,
#        [132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763],
#        [132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763],
#        [132.1763, 132.1763, 132.1763, ..., 132.1763, 132.1763, 132.1763]],
#       shape=(1410, 1471), dtype=float32), 'timestamps': [datetime.datetime(2018, 11, 8, 0, 0)], 'metadata': {'name': 'elevation', 'crs': 'EPSG:5070', 'resolution': 30, 'source': 'USGS/3DEP/1m'}}

# %%
import matplotlib.pyplot as plt

# Access the dictionary inside the 0-d array
elevation_dict = elevation_data.item()

# Plot the elevation data
plt.figure(figsize=(10, 8))
plt.imshow(elevation_dict['data'], cmap='terrain')
plt.colorbar(label='Elevation (m)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Load the fire data .npy file
fire_data = np.load('output/WY4117610642220200917/cc.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()

# %%
# Load the fire data .npy file
fire_data = np.load('output/CA3982012144020181108/cbd.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()

# %%
# Load the fire data .npy file
fire_data = np.load('output/CA3982012144020181108/cc.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()

# %%
import numpy as np

# Load the .npy file
elevation_data = np.load('output/CA3982012144020181108/humidity.npy', allow_pickle=True)

# Show the content
print(elevation_data)
# Out:
# {'data': array([[[10.7, 11. ,  9.8, 11. , 10.8, 10.9, 11.6, 12. , 11.5, 14.2,
#          14.3, 13.2, 10.2],
#         [10.4, 10.5, 10.4, 11.1,  9.7, 11.3, 11.7, 11.7, 13.2, 14. ,
#          13.7, 11.9, 14.3],
#         [10. , 10.6,  9.9, 10.7, 11. , 11.6, 11.1, 13.3, 14.2, 13.7,
#          12.9, 11.9, 17.4],
#         [10.1, 10.4, 10.3,  9.5, 11.2, 11.8, 12.4, 13.3, 12.5, 12.7,
#          12.7, 12.4, 19.9],
#         [ 9.8, 10.7, 10.6,  9.5, 10.3, 11.2, 11.9, 13. , 12.4, 13.8,
#          13.8, 16.3, 16.6],
#         [ 9.7, 10.2, 10.4,  9.9, 11.1, 11.7, 11.6, 13.3, 14.3, 12.3,
#          16.7, 16.8, 17.2],
#         [ 9.6, 10.2, 10.1, 10.2, 11.1, 11.5, 11.5, 12.4, 13.9, 15.2,
#          15.1, 16. , 17.4],
#         [ 9.6, 10.3, 10.4, 10.8, 10.9, 11.4, 11.8, 13.4, 14.8, 15.5,
#          14.1, 14.1, 17.6],
#         [ 9.7, 10.4, 10.6, 10.7, 10.8, 11. , 11.6, 12.6, 12.8, 13.6,
#          15.3, 16.8, 20.3],
#         [ 9.2,  9.7, 10.3, 10.7, 10.9, 11.3, 11.8, 12.7, 14.5, 17.7,
# ...

# %%
# Load the fire data .npy file
fire_data = np.load('output/CA3982012144020181108/humidity.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'][0], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()

# %%
# Load the fire data .npy file
fire_data = np.load('output/CA3982012144020181108/wind_u.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'][0], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()

# %%
# Load the fire data .npy file
fire_data = np.load('output/CA3982012144020181108/wind_v.npy', allow_pickle=True)

# Access the dictionary inside the 0-d array
fire_dict = fire_data.item()

# Plot the fire data
plt.figure(figsize=(10, 8))
plt.imshow(fire_dict['data'][0], interpolation='nearest')
plt.colorbar(label='Fire Intensity')
plt.show()
